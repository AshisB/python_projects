# %%
import pandas as pd

# %%
df=pd.read_csv('data/survey_results_public.csv')

# %%
df.shape
# Out:
# (49123, 170)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49123 entries, 0 to 49122
# Columns: 170 entries, ResponseId to JobSat
# dtypes: float64(50), int64(1), object(119)
# memory usage: 63.7+ MB

# %%
 df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=170)

# %%
df.loc()

# %%
df.iloc[0]
# Out:
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 170, dtype: object

# %%
df.iloc[0]
# Out:
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 170, dtype: object

# %%
df.iloc(0)

# %%
df.iloc[0,1]
# Out:
# 'I am a developer by profession'

# %%
df.iloc[[0,1]]
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
#
#                                            EdLevel Employment  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 1              Associate degree (A.A., A.S., etc.)   Employed
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
#
#                                          LearnCodeAI  ...  \
# ...

# %%
df.iloc([0,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1768\2235276411.py in ?()
# ----> 1 df.iloc([0,1])
#
# ~\PycharmProjects\PythonProject1\PythonProject\python_projects\weather_report\.venv\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     735         # we need to return a copy of ourselves
#     736         new_self = type(self)(self.name, self.obj)
#     737
#     738         if axis is not None:
# --> 739             axis_int_none = self.obj._get_axis_number(axis)
#     740         else:
#     741             axis_int_none = axis
#     742         new_self.axis = axis_int_none
#
# ~\PycharmProjects\PythonProject1\PythonProject\python_projects\weather_report\.venv\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576     @classmethod
#     577     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     578         try:
# ...

# %%
df.iloc[[0,1]]
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
#
#                                            EdLevel Employment  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 1              Associate degree (A.A., A.S., etc.)   Employed
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
#
#                                          LearnCodeAI  ...  \
# ...

# %%
df.iloc[[0,1],1]
# Out:
# 0    I am a developer by profession
# 1    I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.loc[0]
# Out:
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 170, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
#
#                                            EdLevel Employment  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 1              Associate degree (A.A., A.S., etc.)   Employed
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
#
#                                          LearnCodeAI  ...  \
# ...

# %%
df.loc[[0,1],['Age','EdLevel']]
# Out:
#                Age                                          EdLevel
# 0  25-34 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1  25-34 years old              Associate degree (A.A., A.S., etc.)

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (49123, 170)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=170)

# %%
df.LearnCodeChoose
# Out:
# 0        Yes, I am not new to coding but am learning ne...
# 1        Yes, I am not new to coding but am learning ne...
# 2        Yes, I am not new to coding but am learning ne...
# 3        Yes, I am not new to coding but am learning ne...
# 4        No, I am not new to coding and did not learn n...
#                                ...
# 49118    Yes, I am not new to coding but am learning ne...
# 49119    No, I am not new to coding and did not learn n...
# 49120    Yes, I am not new to coding but am learning ne...
# 49121    No, I am not new to coding and did not learn n...
# 49122    No, I am not new to coding and did not learn n...
# Name: LearnCodeChoose, Length: 49123, dtype: object

# %%
df.Age.value_counts()
# Out:
# Age
# 25-34 years old      16485
# 35-44 years old      13232
# 18-24 years old       9195
# 45-54 years old       6265
# 55-64 years old       2626
# 65 years or older      942
# Prefer not to say      378
# Name: count, dtype: int64

# %%
df.loc[:5,['Age','MainBranch']]
# Out:
#                Age                      MainBranch
# 0  25-34 years old  I am a developer by profession
# 1  25-34 years old  I am a developer by profession
# 2  35-44 years old  I am a developer by profession
# 3  35-44 years old  I am a developer by profession
# 4  35-44 years old  I am a developer by profession
# 5  45-54 years old  I am a developer by profession
